# %% [markdown]
# # Takeaways
#
# - ARGO exists but the access method is non-automated
# - We cover a search and data request here...
# - ...and data retrieval with Python ftp
#
#
# # CAHW 4 ARGO
#
# This library sits on GitHub of course; and it is intended to be some'th cut at being an ARGO tool.
# Let's also include some other ARGO references.
#
# - [GitHub pyARGO](https://github.com/castelao/pyARGO) Rob is not convinced this is complete enough to be useful...
# - [UCSD ARGO Informational FAQ](http://www.argo.ucsd.edu/Data_FAQ.html#RorD)
# - [Coriolis map-based data selection tool](http://www.argodatamgt.org/Access-to-data/Argo-data-selection)
# - [xarray lesson that works with ARGO data](https://rabernat.github.io/research_computing/xarray.html)

# %%
# Some Python utility code
from pathlib import Path
home_d = str(Path.home()) + '/'
data_d = home_d + 'data/'             # A non-repository location for datasets of interest

def dirobj(obj): return [x for x in dir(obj) if not x.startswith('__')]

def lsal(path=''):
    import os
    return os.popen('ls -al ' + path).readlines()

def ShowGitHubImage(username, repo, folder, source, localpath, localname, width, height):
    global home_d
    import requests, shutil
    from PIL import Image
    outf = localpath + '/' + localname
    f = 'https://raw.githubusercontent.com/' + username + '/' + repo + '/master/' + folder + '/' + source
    a = requests.get(f, stream = True)
    if a.status_code == 200:
        with open(outf, 'wb') as f:
            a.raw.decode_content = True
            shutil.copyfileobj(a.raw, f)
    return Image.open(outf).resize((width,height),Image.ANTIALIAS)

def ShowLocalImage(path, filename, width, height):
    from PIL import Image
    f = path + '/' + filename 
    return Image.open(f).resize((width,height),Image.ANTIALIAS)

# Test either of the 'Show Image' functions
# ShowGitHubImage('robfatland', 'othermathclub', 'images/cellular', 'conus_textile_shell_2.png', home_d, 'ctextile.jpg', 450, 250)
# ShowLocalImage(home_d, 'ctextile.jpg', 450, 250)

# %%
argo_d = data_d + 'argo/'
ShowLocalImage(argo_d,'argo_coriolis01.png',800,400)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-ff3ec3135bb8> in <module>()
#       1 argo_d = data_d + 'argo/'
# ----> 2 ShowLocalImage(argo_d,'argo_coriolis01.png',800,400)
#
# <ipython-input-4-a581c367734d> in ShowLocalImage(path, filename, width, height)
#      26     from PIL import Image
#      27     f = path + '/' + filename
# ---> 28     return Image.open(f).resize((width,height),Image.ANTIALIAS)
#      29
#      30 # Test either of the 'Show Image' functions
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2578
#    2579     if filename:
# -> 2580         fp = builtins.open(filename, "rb")
#    2581         exclusive_fp = True
#    2582
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jovyan/data/argo//argo_coriolis01.png'

# %% [markdown]
# Coriolis (ARGO data selection tool) says, after a 3-month time window search + download...
# ```
# We are processing your data request.
# The data will be delivered: ftp://ftp.ifremer.fr/ifremer/coriolis/tmp/co0501/DataSelection_20180206_225551_5097076.tgz
# ```

# %% [markdown]
# ### Select a dataset
#
# - Use the map interface to select (as above, yellow rectangle) a bounding box.
# - Use the time box to select a time range
# - Click on Refresh (control left of map), wait for Query to complete
# - Click (or double click?) on Download to open the Data Selection tab in your browser.
#   - This click seems a bit inconsistent... it does not always work
# - Enter your email, click the 'Extract your data' button
# - Receive a 'processing' confirmation email
# - Receive an email with a link to the dataset
#
# I searched for Jan 1 -- June 30 2016. In a matter of five minutes I received a link by email:
#
# ```
# ftp://ftp.ifremer.fr/ifremer/coriolis/tmp/co0501/DataSelection_20180221_193406_5147072.tgz
# ```
#
# Now this file will expire and vanish in an hour or two. When it does the ftp call (cell below) will return
#
# ```
# 221 Goodbye
# ```
#
# So grab that data before it evaporates; and then put it somewhere stable.

# %%
# Jan 1 to June 30 2016 returned...
# ftp://ftp.ifremer.fr/ifremer/coriolis/tmp/co0501/DataSelection_20180221_193406_5147072.tgz
# July 1 to Dec 31 2016...
# ftp://ftp.ifremer.fr/ifremer/coriolis/tmp/co0501/DataSelection_20180221_194041_5147085.tgz,
from ftplib import FTP
dataIDString = '20180221_194041_5147085'
myIDString = './ARGO_Jul1_Dec31_2016.tgz'
ftp = FTP('ftp.ifremer.fr')
ftp.login()
ftp.cwd('ifremer/coriolis/tmp/co0501/')
ftp.retrlines('LIST DataSelection_' + dataIDString + '.tgz')
ftp.retrbinary('RETR DataSelection_' + dataIDString + '.tgz', open(myIDString, 'wb').write)
ftp.quit()
# Out:
# ---------------------------------------------------------------------------
# error_perm                                Traceback (most recent call last)
# <ipython-input-4-75fa02663690> in <module>()
#      10 ftp.cwd('ifremer/coriolis/tmp/co0501/')
#      11 ftp.retrlines('LIST DataSelection_' + dataIDString + '.tgz')
# ---> 12 ftp.retrbinary('RETR DataSelection_' + dataIDString + '.tgz', open(myIDString, 'wb').write)
#      13 ftp.quit()
#
# /usr/lib/python3.5/ftplib.py in retrbinary(self, cmd, callback, blocksize, rest)
#     439         """
#     440         self.voidcmd('TYPE I')
# --> 441         with self.transfercmd(cmd, rest) as conn:
#     442             while 1:
#     443                 data = conn.recv(blocksize)
#
# /usr/lib/python3.5/ftplib.py in transfercmd(self, cmd, rest)
#     396     def transfercmd(self, cmd, rest=None):
#     397         """Like ntransfercmd() but returns only the socket."""
# --> 398         return self.ntransfercmd(cmd, rest)[0]
#     399
#     400     def login(self, user = '', passwd = '', acct = ''):
#
# /usr/lib/python3.5/ftplib.py in ntransfercmd(self, cmd, rest)
#     362                 if rest is not None:
#     363                     self.sendcmd("REST %s" % rest)
# --> 364                 resp = self.sendcmd(cmd)
#     365                 # Some servers apparently send a 200 reply to
#     366                 # a LIST or STOR command, before the 150 reply
#
# /usr/lib/python3.5/ftplib.py in sendcmd(self, cmd)
#     270         '''Send a command and return the response.'''
#     271         self.putcmd(cmd)
# --> 272         return self.getresp()
#     273
#     274     def voidcmd(self, cmd):
#
# /usr/lib/python3.5/ftplib.py in getresp(self)
#     243             raise error_temp(resp)
#     244         if c == '5':
# --> 245             raise error_perm(resp)
#     246         raise error_proto(resp)
#     247
#
# error_perm: 550 Failed to open file.

# %%
import os

def ls(qual):
    return os.popen('ls -al ' + qual).readlines()
    
datasetList = []
r = ls('*.tgz')
for a in r: 
    c = a.split(' ')[8].split('.')[0]
    if c not in datasetList: datasetList.append(c)
        
print(str(datasetList))
# Out:
# ['ARGO_Jul1_Dec31_2016']

# %%
for c in datasetList:
    retvalue = os.popen('gunzip ' + c + '.tgz').readlines()
    retvalue = os.popen('tar -xvf ' + c + '.tar').readlines()
# !tar -xvf coriolis_profiles.tgz
# !rm /data/argo/coriolis_profiles.tgz
# !mkdir /data/argo/profiles
# !mkdir /data/argo/trajectories

# %%
# Broken... skip this for now
# import anaconda
# from argo.argo import profile_from_nc
# from argo.utils import download_testdata
# datafile = download_testdata('20150127_prof.nc')

# %% [markdown]
# ## ARGO Data
#
# The main data resource is a pair of Global Data Assembly Centers (GDACs) in US and France.
# The data are in NetCDF format and one should use 'D' files when possible (in contrast with 'R' files):
# These D files have been post-processed (quality control).
#
#
# There are other ways to access Argo data besides downloading the netCDF files from the GDACs.
# There are gridded fields and velocity products available as well as data viewers developed to look at the Argo dataset.
# To look at individual float data, use the individual float description tool at Coriolis.
# To select a group of floats within a certain region or time, use one of the data selection tools to the right.
# There is also a beginner's guide to Argo data.

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import pandas as pd
import netCDF4
import xarray as xr
import numpy as np

r = ls('./argo/*.nc')
r
fl = []
ds = []
for a in r:
    b = a.split(' ')   
    for c in b:
        if 'argo-' in c:
            d = c.split('/')[2]
            if d not in fl: 
                fl.append(d.rstrip('\n'))
                f = './argo/' + fl[-1]
                # print(f)
                ds.append(xr.open_mfdataset(f))

# dir(ds[0])
ds[0].keys
# Out:
# <bound method Mapping.keys of <xarray.Dataset>
# Dimensions:                       (N_CALIB: 1, N_HISTORY: 9, N_LEVELS: 1002, N_PARAM: 3, N_PROF: 18)
# Dimensions without coordinates: N_CALIB, N_HISTORY, N_LEVELS, N_PARAM, N_PROF
# Data variables:
#     DATA_TYPE                     object ...
#     FORMAT_VERSION                object ...
#     HANDBOOK_VERSION              object ...
#     REFERENCE_DATE_TIME           object ...
#     DATE_CREATION                 object ...
#     DATE_UPDATE                   object ...
#     PLATFORM_NUMBER               (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PROJECT_NAME                  (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PI_NAME                       (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     STATION_PARAMETERS            (N_PROF, N_PARAM) object dask.array<shape=(18, 3), chunksize=(18, 3)>
#     CYCLE_NUMBER                  (N_PROF) float64 dask.array<shape=(18,), chunksize=(18,)>
#     DIRECTION                     (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     DATA_CENTRE                   (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     DC_REFERENCE                  (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     DATA_STATE_INDICATOR          (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     DATA_MODE                     (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PLATFORM_TYPE                 (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     FLOAT_SERIAL_NO               (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     FIRMWARE_VERSION              (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     WMO_INST_TYPE                 (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     JULD                          (N_PROF) datetime64[ns] dask.array<shape=(18,), chunksize=(18,)>
#     JULD_QC                       (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     JULD_LOCATION                 (N_PROF) datetime64[ns] dask.array<shape=(18,), chunksize=(18,)>
#     LATITUDE                      (N_PROF) float64 dask.array<shape=(18,), chunksize=(18,)>
#     LONGITUDE                     (N_PROF) float64 dask.array<shape=(18,), chunksize=(18,)>
#     POSITION_QC                   (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     POSITIONING_SYSTEM            (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PROFILE_PRES_QC               (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PROFILE_PSAL_QC               (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     PROFILE_TEMP_QC               (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     VERTICAL_SAMPLING_SCHEME      (N_PROF) object dask.array<shape=(18,), chunksize=(18,)>
#     CONFIG_MISSION_NUMBER         (N_PROF) float64 dask.array<shape=(18,), chunksize=(18,)>
#     PRES                          (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PRES_QC                       (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PRES_ADJUSTED                 (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PRES_ADJUSTED_QC              (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PRES_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PSAL                          (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PSAL_QC                       (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PSAL_ADJUSTED                 (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PSAL_ADJUSTED_QC              (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PSAL_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     TEMP                          (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     TEMP_QC                       (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     TEMP_ADJUSTED                 (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     TEMP_ADJUSTED_QC              (N_PROF, N_LEVELS) object dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     TEMP_ADJUSTED_ERROR           (N_PROF, N_LEVELS) float64 dask.array<shape=(18, 1002), chunksize=(18, 1002)>
#     PARAMETER                     (N_PROF, N_CALIB, N_PARAM) object dask.array<shape=(18, 1, 3), chunksize=(18, 1, 3)>
#     SCIENTIFIC_CALIB_EQUATION     (N_PROF, N_CALIB, N_PARAM) object dask.array<shape=(18, 1, 3), chunksize=(18, 1, 3)>
#     SCIENTIFIC_CALIB_COEFFICIENT  (N_PROF, N_CALIB, N_PARAM) object dask.array<shape=(18, 1, 3), chunksize=(18, 1, 3)>
#     SCIENTIFIC_CALIB_COMMENT      (N_PROF, N_CALIB, N_PARAM) object dask.array<shape=(18, 1, 3), chunksize=(18, 1, 3)>
#     SCIENTIFIC_CALIB_DATE         (N_PROF, N_CALIB, N_PARAM) object dask.array<shape=(18, 1, 3), chunksize=(18, 1, 3)>
#     HISTORY_INSTITUTION           (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_STEP                  (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_SOFTWARE              (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_SOFTWARE_RELEASE      (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_REFERENCE             (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_DATE                  (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_ACTION                (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_PARAMETER             (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_START_PRES            (N_HISTORY, N_PROF) float64 dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_STOP_PRES             (N_HISTORY, N_PROF) float64 dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_PREVIOUS_VALUE        (N_HISTORY, N_PROF) float64 dask.array<shape=(9, 18), chunksize=(9, 18)>
#     HISTORY_QCTEST                (N_HISTORY, N_PROF) object dask.array<shape=(9, 18), chunksize=(9, 18)>
# Attributes:
#     title:                Argo float vertical profile
#     institution:          AOML
#     source:               Argo float
#     history:              2018-02-21T19:41:05Z creation
#     references:           http://www.argodatamgt.org/Documentation
#     comment:
#     user_manual_version:  3.03
#     Conventions:          Argo-3.0 CF-1.6
#     featureType:          trajectoryProfile>

# %%
ds[0].keys
df = ds[0]['TEMP'].to_dataframe()

# %%
# %%time
plt.close()
fig,ax = plt.subplots()
fig.set_size_inches(16,6)
df['TEMP'].plot()
# Out:
# CPU times: user 136 ms, sys: 0 ns, total: 136 ms
# Wall time: 121 ms

# %%
U = c['PRES']
dir(U)
# U.plot()
# Out:
# ['C_format',
#  'FORTRAN_format',
#  'N_LEVELS',
#  'N_PROF',
#  'T',
#  '_DataArray__default',
#  '_DataArray__default_name',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__dask_graph__',
#  '__dask_keys__',
#  '__dask_optimize__',
#  '__dask_postcompute__',
#  '__dask_postpersist__',
#  '__dask_scheduler__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_all_compat',
#  '_attr_sources',
#  '_binary_op',
#  '_calc_assign_results',
#  '_copy_attrs_from',
#  '_cum_extra_args_docstring',
#  '_dask_finalize',
#  '_from_temp_dataset',
#  '_get_axis_num',
#  '_getitem_coord',
#  '_groupby_cls',
#  '_in_memory',
#  '_initialized',
#  '_inplace_binary_op',
#  '_ipython_key_completions_',
#  '_item_key_to_dict',
#  '_item_sources',
#  '_iter',
#  '_level_coords',
#  '_reduce_extra_args_docstring',
#  '_reduce_method',
#  '_replace',
#  '_replace_indexes',
#  '_replace_maybe_drop_dims',
#  '_resample_cls',
#  '_resample_immediately',
#  '_result_name',
#  '_rolling_cls',
#  '_title_for_slice',
#  '_to_dataset_split',
#  '_to_dataset_whole',
#  '_to_temp_dataset',
#  '_unary_op',
#  'all',
#  'any',
#  'argmax',
#  'argmin',
#  'argsort',
#  'assign_attrs',
#  'assign_coords',
#  'astype',
#  'attrs',
#  'axis',
#  'broadcast_equals',
#  'chunk',
#  'chunks',
#  'clip',
#  'close',
#  'combine_first',
#  'compute',
#  'conj',
#  'conjugate',
#  'coords',
#  'copy',
#  'count',
#  'cumprod',
#  'cumsum',
#  'data',
#  'diff',
#  'dims',
#  'dot',
#  'drop',
#  'dropna',
#  'dt',
#  'dtype',
#  'encoding',
#  'equals',
#  'expand_dims',
#  'fillna',
#  'from_cdms2',
#  'from_dict',
#  'from_series',
#  'get_axis_num',
#  'get_index',
#  'groupby',
#  'groupby_bins',
#  'identical',
#  'imag',
#  'indexes',
#  'isel',
#  'isel_points',
#  'isnull',
#  'item',
#  'load',
#  'loc',
#  'long_name',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'name',
#  'nbytes',
#  'ndim',
#  'notnull',
#  'persist',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'real',
#  'reduce',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'reorder_levels',
#  'resample',
#  'reset_coords',
#  'reset_index',
#  'resolution',
#  'roll',
#  'rolling',
#  'round',
#  'searchsorted',
#  'sel',
#  'sel_points',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'sizes',
#  'sortby',
#  'squeeze',
#  'stack',
#  'standard_name',
#  'std',
#  'sum',
#  'swap_dims',
#  'to_cdms2',
#  'to_dataframe',
#  'to_dataset',
#  'to_dict',
#  'to_index',
#  'to_masked_array',
#  'to_netcdf',
#  'to_pandas',
#  'to_series',
#  'transpose',
#  'units',
#  'unstack',
#  'valid_max',
#  'valid_min',
#  'values',
#  'var',
#  'variable',
#  'where']

# %%
dir(U.T)
# Out:
# ['C_format',
#  'FORTRAN_format',
#  'N_LEVELS',
#  'N_PROF',
#  'T',
#  '_DataArray__default',
#  '_DataArray__default_name',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__dask_graph__',
#  '__dask_keys__',
#  '__dask_optimize__',
#  '__dask_postcompute__',
#  '__dask_postpersist__',
#  '__dask_scheduler__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_all_compat',
#  '_attr_sources',
#  '_binary_op',
#  '_calc_assign_results',
#  '_copy_attrs_from',
#  '_cum_extra_args_docstring',
#  '_dask_finalize',
#  '_from_temp_dataset',
#  '_get_axis_num',
#  '_getitem_coord',
#  '_groupby_cls',
#  '_in_memory',
#  '_initialized',
#  '_inplace_binary_op',
#  '_ipython_key_completions_',
#  '_item_key_to_dict',
#  '_item_sources',
#  '_iter',
#  '_level_coords',
#  '_reduce_extra_args_docstring',
#  '_reduce_method',
#  '_replace',
#  '_replace_indexes',
#  '_replace_maybe_drop_dims',
#  '_resample_cls',
#  '_resample_immediately',
#  '_result_name',
#  '_rolling_cls',
#  '_title_for_slice',
#  '_to_dataset_split',
#  '_to_dataset_whole',
#  '_to_temp_dataset',
#  '_unary_op',
#  'all',
#  'any',
#  'argmax',
#  'argmin',
#  'argsort',
#  'assign_attrs',
#  'assign_coords',
#  'astype',
#  'attrs',
#  'axis',
#  'broadcast_equals',
#  'chunk',
#  'chunks',
#  'clip',
#  'close',
#  'combine_first',
#  'compute',
#  'conj',
#  'conjugate',
#  'coords',
#  'copy',
#  'count',
#  'cumprod',
#  'cumsum',
#  'data',
#  'diff',
#  'dims',
#  'dot',
#  'drop',
#  'dropna',
#  'dt',
#  'dtype',
#  'encoding',
#  'equals',
#  'expand_dims',
#  'fillna',
#  'from_cdms2',
#  'from_dict',
#  'from_series',
#  'get_axis_num',
#  'get_index',
#  'groupby',
#  'groupby_bins',
#  'identical',
#  'imag',
#  'indexes',
#  'isel',
#  'isel_points',
#  'isnull',
#  'item',
#  'load',
#  'loc',
#  'long_name',
#  'max',
#  'mean',
#  'median',
#  'min',
#  'name',
#  'nbytes',
#  'ndim',
#  'notnull',
#  'persist',
#  'pipe',
#  'plot',
#  'prod',
#  'quantile',
#  'real',
#  'reduce',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'reorder_levels',
#  'resample',
#  'reset_coords',
#  'reset_index',
#  'resolution',
#  'roll',
#  'rolling',
#  'round',
#  'searchsorted',
#  'sel',
#  'sel_points',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'sizes',
#  'sortby',
#  'squeeze',
#  'stack',
#  'standard_name',
#  'std',
#  'sum',
#  'swap_dims',
#  'to_cdms2',
#  'to_dataframe',
#  'to_dataset',
#  'to_dict',
#  'to_index',
#  'to_masked_array',
#  'to_netcdf',
#  'to_pandas',
#  'to_series',
#  'transpose',
#  'units',
#  'unstack',
#  'valid_max',
#  'valid_min',
#  'values',
#  'var',
#  'variable',
#  'where']

# %%
dir(U.data)
# Out:
# ['A',
#  'T',
#  '__abs__',
#  '__abstractmethods__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__dask_graph__',
#  '__dask_keys__',
#  '__dask_optimize__',
#  '__dask_postcompute__',
#  '__dask_postpersist__',
#  '__dask_scheduler__',
#  '__dask_tokenize__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdiv__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__xor__',
#  '_abc_cache',
#  '_abc_negative_cache',
#  '_abc_negative_cache_version',
#  '_abc_registry',
#  '_cached_keys',
#  '_chunks',
#  '_elemwise',
#  '_finalize',
#  '_get',
#  '_get_chunks',
#  '_keys',
#  '_name',
#  '_optimize',
#  '_scalarfunc',
#  '_set_chunks',
#  '_vindex',
#  'all',
#  'any',
#  'argmax',
#  'argmin',
#  'astype',
#  'choose',
#  'chunks',
#  'clip',
#  'compute',
#  'conj',
#  'copy',
#  'cumprod',
#  'cumsum',
#  'dask',
#  'dot',
#  'dtype',
#  'flatten',
#  'imag',
#  'itemsize',
#  'map_blocks',
#  'map_overlap',
#  'max',
#  'mean',
#  'min',
#  'moment',
#  'name',
#  'nbytes',
#  'ndim',
#  'nonzero',
#  'npartitions',
#  'numblocks',
#  'persist',
#  'prod',
#  'ravel',
#  'real',
#  'rechunk',
#  'repeat',
#  'reshape',
#  'round',
#  'shape',
#  'size',
#  'squeeze',
#  'std',
#  'store',
#  'sum',
#  'swapaxes',
#  'to_dask_dataframe',
#  'to_delayed',
#  'to_hdf5',
#  'topk',
#  'transpose',
#  'var',
#  'view',
#  'vindex',
#  'visualize',
#  'vnorm']

# %%
U.data.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-48d134cd0370> in <module>()
# ----> 1 U.data.plot()
#
# AttributeError: 'Array' object has no attribute 'plot'

# %%
b.PRES.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-e0cd01b9bc96> in <module>()
# ----> 1 b.PRES.plot()
#
# AttributeError: 'NpzFile' object has no attribute 'PRES'

# %%
print (b['PRES'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-fe31ef1b7a3c> in <module>()
# ----> 1 print (b['PRES'])
#
# /opt/anaconda/envs/x3/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     235                 return self.zip.read(key)
#     236         else:
# --> 237             raise KeyError("%s is not a file in the archive" % key)
#     238
#     239     def __iter__(self):
#
# KeyError: 'PRES is not a file in the archive'

# %%
dir(b['PRES'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e8f5a33af3cb> in <module>()
# ----> 1 dir(b['PRES'])
#
# /opt/anaconda/envs/x3/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     235                 return self.zip.read(key)
#     236         else:
# --> 237             raise KeyError("%s is not a file in the archive" % key)
#     238
#     239     def __iter__(self):
#
# KeyError: 'PRES is not a file in the archive'

# %%
dir(b['PRES']['data'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-8d3be789ad8c> in <module>()
# ----> 1 dir(b['PRES']['data'])
#
# /opt/anaconda/envs/x3/lib/python3.6/site-packages/numpy/lib/npyio.py in __getitem__(self, key)
#     235                 return self.zip.read(key)
#     236         else:
# --> 237             raise KeyError("%s is not a file in the archive" % key)
#     238
#     239     def __iter__(self):
#
# KeyError: 'PRES is not a file in the archive'

# %%
b.keys()
# Out:
# ['S', 'T', 'levels', 'lon', 'date', 'P', 'lat']

# %%
print(b.psal.shap())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-dc7ea6b3053b> in <module>()
# ----> 1 print(b.psal.shap())
#
# AttributeError: 'NpzFile' object has no attribute 'psal'

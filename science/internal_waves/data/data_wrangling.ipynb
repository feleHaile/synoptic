# %%
import re
import xarray as xr
import numpy as np
import os
import requests
import matplotlib.pyplot as plt
from datetime import datetime

# %%
url = 'https://opendap.oceanobservatories.org/thredds/catalog/ooi/friedrich.knuth@rutgers.edu/20180423T142423-RS01SBPS-PC01A-05-ADCPTD102-streamed-adcp_velocity_beam/catalog.html'
tds_url = 'https://opendap.oceanobservatories.org/thredds/dodsC'
datasets = requests.get(url).text
urls = re.findall(r'href=[\'"]?([^\'" >]+)', datasets)
x = re.findall(r'(ooi/.*?.nc)', datasets)
for i in x:
    if i.endswith('.nc') == False:
        x.remove(i)
for i in x:
    try:
        float(i[-4])
    except:
        x.remove(i)
datasets = [os.path.join(tds_url, i) for i in x]

# %%
# make the output directory
new_dir = 'minute_mean_data/'
if not os.path.isdir(new_dir):
    try:
        os.makedirs(new_dir)
    except OSError:
        if os.path.exists(new_dir):
            pass
        else:
            raise

# %%
# datasets = ['https://opendap.oceanobservatories.org/thredds/dodsC/ooi/friedrich.knuth@rutgers.edu/20180423T142423-RS01SBPS-PC01A-05-ADCPTD102-streamed-adcp_velocity_beam/deployment0001_RS01SBPS-PC01A-05-ADCPTD102-streamed-adcp_velocity_beam_20150529T000000.660000-20150531T235959.850000.nc']
ds = xr.open_mfdataset(datasets)
ds = ds.swap_dims({'obs': 'time'})
ds = ds.chunk({'time': 100})

# %%
time = ds['time'].data
bin_depths = ds['bin_depths'].data.T
east = ds['eastward_seawater_velocity'].data.T
north = ds['northward_seawater_velocity'].data.T
up = ds['upward_seawater_velocity'].data.T

# %%
lim_east = float("%2.2f" % np.nanpercentile(east, 90))
lim_north = float("%2.2f" % np.nanpercentile(north, 90))
lim_up = float("%2.2f" % np.nanpercentile(up, 90))

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
p = ax.pcolormesh(time, bin_depths, east, cmap='RdBu',vmin=-lim_east,vmax=lim_east)
ax.set_ylim(20,200)
ax.invert_yaxis()
fig.colorbar(p)

# %%
fig.savefig('out.png')

# %%
time = ds['time']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-587e0ddb8ce6> in <module>()
# ----> 1 time = ds['time'].values.to_list()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_list'

# %%
# read in the data directly off THREDDS and write out as subsampled pickled pandas dataframe
num = 0
for i in datasets:
    ds = xr.open_dataset(i)
    ds = ds.swap_dims({'obs': 'time'})

    pressure_min = pd.DataFrame()
    pressure_min['bottom_pressure'] = ds['bottom_pressure'].to_pandas().resample('T').mean()
    del pressure_min.index.name

    pressure_min = pressure_min.dropna()

    out = 'minute_mean_data/' + i.split('/')[-1][:-3] + '_resampled' + '.pd'
    num = num +1

    with open(out, 'wb') as fh:
        pk.dump(pressure_min,fh)

    gc.collect()

# %%
# datasets = ['https://opendap.oceanobservatories.org/thredds/dodsC/ooi/friedrich.knuth@rutgers.edu/20180423T142423-RS01SBPS-PC01A-05-ADCPTD102-streamed-adcp_velocity_beam/deployment0001_RS01SBPS-PC01A-05-ADCPTD102-streamed-adcp_velocity_beam_20150529T000000.660000-20150531T235959.850000.nc']
ds = xr.open_mfdataset(datasets)
ds = ds.swap_dims({'obs': 'time'})
ds = ds.chunk({'time': 100})

# %%
ds['correlation_magnitude_beam1']
# Out:
# <xarray.Dataset>
# Dimensions:                         (bin: 30, time: 1402579)
# Coordinates:
#     obs                             (time) int64 dask.array<shape=(1402579,), chunksize=(100,)>
#   * time                            (time) datetime64[ns] 2015-06-03T00:00:00.670000128 ...
#     pressure                        (time) float64 dask.array<shape=(1402579,), chunksize=(100,)>
#     lat                             (time) float64 dask.array<shape=(1402579,), chunksize=(100,)>
#     lon                             (time) float64 dask.array<shape=(1402579,), chunksize=(100,)>
# Dimensions without coordinates: bin
# Data variables:
#     deployment                      (time) int32 dask.array<shape=(1402579,), chunksize=(100,)>
#     id                              (time) |S64 dask.array<shape=(1402579,), chunksize=(100,)>
#     bin_1_distance                  (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     cell_length                     (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     correlation_magnitude_beam1     (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam2     (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam3     (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     correlation_magnitude_beam4     (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     driver_timestamp                (time) datetime64[ns] dask.array<shape=(1402579,), chunksize=(100,)>
#     echo_intensity_beam1            (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     echo_intensity_beam2            (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     echo_intensity_beam3            (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     echo_intensity_beam4            (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     ensemble_number                 (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     heading                         (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     ingestion_timestamp             (time) datetime64[ns] dask.array<shape=(1402579,), chunksize=(100,)>
#     internal_timestamp              (time) datetime64[ns] dask.array<shape=(1402579,), chunksize=(100,)>
#     num_cells                       (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     percent_good_beam1              (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     percent_good_beam2              (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     percent_good_beam3              (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     percent_good_beam4              (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     pitch                           (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     port_timestamp                  (time) datetime64[ns] dask.array<shape=(1402579,), chunksize=(100,)>
#     preferred_timestamp             (time) object dask.array<shape=(1402579,), chunksize=(100,)>
#     provenance                      (time) |S64 dask.array<shape=(1402579,), chunksize=(100,)>
#     quality_flag                    (time) |S64 dask.array<shape=(1402579,), chunksize=(100,)>
#     roll                            (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     salinity                        (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     sysconfig_vertical_orientation  (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     temperature                     (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     transducer_depth                (time) float32 dask.array<shape=(1402579,), chunksize=(100,)>
#     velocity_beam1                  (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     velocity_beam2                  (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     velocity_beam3                  (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     velocity_beam4                  (time, bin) float32 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam1  (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam2  (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam3  (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     corrected_echo_intensity_beam4  (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     eastward_seawater_velocity      (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     northward_seawater_velocity     (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     upward_seawater_velocity        (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     error_seawater_velocity         (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
#     bin_depths                      (time, bin) float64 dask.array<shape=(1402579, 30), chunksize=(100, 30)>
# Attributes:
#     _NCProperties:                      version=1|netcdflibversion=4.4.1.1|hd...
#     node:                               PC01A
#     comment:
#     publisher_email:
#     sourceUrl:                          http://oceanobservatories.org/
#     collection_method:                  streamed
#     stream:                             adcp_velocity_beam
#     featureType:                        point
#     creator_email:
#     publisher_name:                     Ocean Observatories Initiative
#     date_modified:                      2018-04-23T14:27:41.692850
#     keywords:
#     cdm_data_type:                      Point
#     references:                         More information can be found at http...
#     Metadata_Conventions:               Unidata Dataset Discovery v1.0
#     date_created:                       2018-04-23T14:27:41.692845
#     id:                                 RS01SBPS-PC01A-05-ADCPTD102-streamed-...
#     requestUUID:                        8e8c9336-a010-4f98-bf22-00ec445260e2
#     contributor_role:
#     summary:                            Dataset Generated by Stream Engine fr...
#     keywords_vocabulary:
#     institution:                        Ocean Observatories Initiative
#     naming_authority:                   org.oceanobservatories
#     feature_Type:                       point
#     infoUrl:                            http://oceanobservatories.org/
#     license:
#     contributor_name:
#     uuid:                               8e8c9336-a010-4f98-bf22-00ec445260e2
#     creator_name:                       Ocean Observatories Initiative
#     title:                              Data produced by Stream Engine versio...
#     sensor:                             05-ADCPTD102
#     standard_name_vocabulary:           NetCDF Climate and Forecast (CF) Meta...
#     acknowledgement:
#     Conventions:                        CF-1.6
#     project:                            Ocean Observatories Initiative
#     source:                             RS01SBPS-PC01A-05-ADCPTD102-streamed-...
#     publisher_url:                      http://oceanobservatories.org/
#     creator_url:                        http://oceanobservatories.org/
#     nodc_template_version:              NODC_NetCDF_TimeSeries_Orthogonal_Tem...
#     subsite:                            RS01SBPS
#     processing_level:                   L2
#     history:                            2018-04-23T14:27:41.692795 generated ...
#     Manufacturer:                       Teledyne RDI
#     ModelNumber:                        WHM150-1500
#     SerialNumber:                       18980
#     Description:                        ADCP Velocity Profiler (short range):...
#     FirmwareVersion:                    Not specified.
#     SoftwareVersion:                    Not specified.
#     AssetUniqueID:                      ATAPL-58315-00003
#     Notes:                              Not specified.
#     Owner:                              University of Washington
#     RemoteResources:                    []
#     ShelfLifeExpirationDate:            Not specified.
#     Mobile:                             False
#     AssetManagementRecordLastModified:  2018-04-17T19:02:12.456000
#     time_coverage_start:                2015-06-03T00:00:00.670000
#     time_coverage_end:                  2015-06-05T01:01:00.500000
#     time_coverage_resolution:           P0.80S
#     geospatial_lat_min:                 44.52897
#     geospatial_lat_max:                 44.52897
#     geospatial_lat_units:               degrees_north
#     geospatial_lat_resolution:          0.1
#     geospatial_lon_min:                 -125.38937
#     geospatial_lon_max:                 -125.38937
#     geospatial_lon_units:               degrees_east
#     geospatial_lon_resolution:          0.1
#     geospatial_vertical_units:          meters
#     geospatial_vertical_resolution:     0.1
#     geospatial_vertical_positive:       down
#     DODS.strlen:                        2
#     DODS.dimName:                       string2
#     DODS_EXTRA.Unlimited_Dimension:     obs

# %%
east

# %%
x

# %%
u_v_w = np.concatenate(east, north, up)
lim = float("%2.2f" % np.nanpercentile(abs(u_v_w), 90))

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 10)
p = ax.pcolormesh(time, bins, east, cmap='RdBu',vmin=-lim,vmax=lim)
ax.set_ylim(20,200)
ax.invert_yaxis()
fig.colorbar(p)

# %%
start = datetime.strptime('2015-05-29','%Y-%m-%d')
end = datetime.strptime('2015-05-30','%Y-%m-%d')

# %%
ds_slice = ds.sel(time=slice(start, end))

# %%
# horizontal_data = np.concatenate(north)

# %%
fig, ax = plt.subplots()
p = ax.pcolormesh(time, bins, north, cmap='RdBu',vmin=-lim,vmax=lim)
ax.set_ylim(20,200)
ax.invert_yaxis()
cb = fig.colorbar(p)
cb.update_ticks()
cb.formatter.set_useOffset(False)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(16, 6);
ax.invert_yaxis()
ax.grid()
ax.set_xlim(x[0],x[-1])
sc = plt.scatter(x, y, c=z)
cb = fig.colorbar(sc, ax=ax)
cb.update_ticks()
cb.formatter.set_useOffset(False)
plt.show()

# %%
df = ds.to_dataframe()

# %%
df_east = ds['eastward_seawater_velocity'].to_pandas()

# %%
df_east

# %%
df_east.index.get_level_values

# %%
test = df['eastward_seawater_velocity'].resample('T').mean()

# %%
    pressure_min = pd.DataFrame()
    pressure_min['bottom_pressure'] = ds['bottom_pressure'].to_pandas().resample('T').mean()

# %%
ds.time.min()

# %%
ds.time.max()

# %%
ds1

# %%
time = ds1['time'].values
bins = ds1['bin_depths'].values
north = ds1['northward_seawater_velocity'].values
east = ds1['eastward_seawater_velocity'].values
up = ds1['upward_seawater_velocity'].values

# %%
fig, ax = plt.subplots()
ax.pcolormesh(time, bins, north)

fig.set_size_inches(16, 6);
# ax.invert_yaxis()
# ax.grid()
# ax.set_xlim(x[0],x[-1])
# sc = plt.scatter(x, y, c=z)
# cb = fig.colorbar(sc, ax=ax)
# cb.update_ticks()
# cb.formatter.set_useOffset(False)
# plt.show()
